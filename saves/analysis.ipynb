# %% [markdown]
# # Distrobution of Populations

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def pop_hist(filename, title):
    pop_f = open(filename,'r')
    pop = [l.strip('\n') for l in pop_f.readlines()]
#     print(*pop, sep='\n')
    genes = []
    for genome in pop:
        genes += [int(g) for g in genome.split(' ')[:-1]]
#     print(genes)
    plt.title(title)
    plt.hist(genes)
    plt.show()
    

pop_hist('phrases.np', 'Phrases')
pop_hist('measures.np', 'Measures')
